# %%
#Libraries
import pandas as pd
import numpy as np
from sklearn import svm
from sklearn.svm import SVR

#visaualization
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(font_scale=1.5)

# %%
wine = pd.read_csv("winequalityN-white.csv")
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
X = wine.drop('quality', axis = 1) #storing the quality as labels
X = X.interpolate(method='linear', limit_direction='forward', axis=0) # intepolating NaN values

y = wine['quality']
y = y.interpolate(method='linear', limit_direction='forward', axis=0)

X,y
# Out:
# (      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
#  0               7.0             0.270         0.36           20.70      0.045
#  1               6.3             0.300         0.34            1.60      0.049
#  2               8.1             0.280         0.40            6.90      0.050
#  3               7.2             0.230         0.32            8.50      0.058
#  4               7.2             0.230         0.32            8.50      0.058
#  5               8.1             0.280         0.40            6.90      0.050
#  6               6.2             0.320         0.16            7.00      0.045
#  7               7.0             0.270         0.36           20.70      0.045
#  8               6.3             0.300         0.34            1.60      0.049
#  9               8.1             0.220         0.43            1.50      0.044
#  10              8.1             0.270         0.41            1.45      0.033
# ...

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33)

print(X_train)
print(y_train)
print(X_test)
print(y_test)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4029            6.8             0.300         0.27           11.60      0.028
# 3689            6.5             0.350         0.38            7.40      0.036
# 409             7.0             0.210         0.28            8.70      0.045
# 613             7.0             0.230         0.42           18.05      0.050
# 2357            7.0             0.230         0.42            5.10      0.042
# 611             5.8             0.310         0.33            1.20      0.036
# 1736            6.4             0.280         0.19            5.40      0.042
# 913             6.1             0.270         0.44            6.70      0.041
# 3744            7.4             0.270         0.31            2.40      0.014
# 2721            6.7             0.440         0.22            4.30      0.032
# 3904            6.1             0.280         0.26            1.50      0.030
# ...

# %%
Xtrain_norm = (X_train - X_train.min()) / (X_train.max() - X_train.min())
ytrain_norm = (y_train - y_train.min()) / (y_train.max() - y_train.min())
#Xtrain_norm
#ytrain_norm

# %%
Xtest_norm = (X_test - X_test.min()) / (X_test.max() - X_test.min())
ytest_norm = (y_test - y_test.min()) / (y_test.max() - y_test.min())
ytest_norm
# Out:
# 1719    0.6
# 2313    0.2
# 3981    0.4
# 1183    0.4
# 2076    0.4
# 3566    0.8
# 3768    0.4
# 4336    0.6
# 1227    0.4
# 1105    0.8
# 1233    0.6
# 3575    0.8
# 4790    0.6
# 3303    0.6
# 4576    0.6
# 3337    0.6
# 1385    0.6
# 73      0.8
# 335     0.8
# 907     0.4
# 1324    1.0
# 60      0.6
# 3169    0.6
# 3264    0.4
# 3646    1.0
# 3462    0.6
# 1075    0.8
# 697     0.6
# 1495    0.4
# 3641    1.0
#        ...
# 2146    0.8
# 506     0.6
# 2389    0.2
# 2197    0.6
# 2410    0.6
# 2768    0.4
# 3325    0.6
# 2609    0.4
# 2909    0.2
# 3443    0.6
# 4435    0.6
# 4157    0.8
# 3347    0.8
# 1827    0.6
# 1319    0.6
# 404     0.6
# 2867    0.6
# 4685    0.6
# 4284    0.6
# 3321    0.6
# 2228    0.4
# 2783    0.4
# 3163    0.4
# 157     0.6
# 1528    0.8
# 2093    0.4
# 955     0.8
# 2024    0.4
# 3602    0.6
# 2504    0.6
# Name: quality, Length: 1608, dtype: float64

# %%
model = svm.SVR(kernel='rbf')
model.fit(Xtrain_norm, ytrain_norm)
# Out:
# C:\Users\ocanbek3\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)

# %%
#mean_trainingX = Xtrain_norm.mean()
#mean_trainingX = Xtrain_norm.mean()
#mean_trainingX

# %%
y_pred = model.predict(Xtest_norm)
print(y_pred)
# Out:
# [0.36663431 0.37745522 0.36410871 ... 0.36641529 0.33394868 0.41190505]

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from math import sqrt

rms = sqrt(mean_squared_error(ytest_norm, y_pred))
mae = mean_absolute_error(ytest_norm, y_pred)
print(rms)
print(mae)
# Out:
# 0.19324782969412954
# 0.1536797193958816

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model,X, y, cv=5)
scores
# Out:
# C:\Users\ocanbek3\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\ocanbek3\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\ocanbek3\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
# ...

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=3) # Define the split - into 3 folds 
kf.get_n_splits(Xtrain_norm)
print(kf.split(Xtrain_norm))
#print(Xtrain_norm.shape)

# %%
from sklearn import preprocessing
#normalization for features
f_array = np.array(wine['fixed acidity'])
n_f = preprocessing.normalize([f_array]) #normalized fixed acidity
v_array = np.array(wine['volatile acidity'])
n_v = preprocessing.normalize([v_array]) #normalized volatile acidity
c_array = np.array(wine['citric acid'])
n_c = preprocessing.normalize([c_array]) #normalized citric acid
r_array = np.array(wine['residual sugar'])
n_r = preprocessing.normalize([r_array]) #normalized residual sugar
ch_array = np.array(wine['chlorides'])
n_ch = preprocessing.normalize([ch_array]) #normalized chlorides
fsd_array = np.array(wine['free sulfur dioxide'])
n_fsd = preprocessing.normalize([fsd_array]) #normalized free sulfur dioxide
tsd_array = np.array(wine['total sulfur dioxide'])
n_tsd = preprocessing.normalize([tsd_array]) #normalized total sulfur dioxide
d_array = np.array(wine['density'])
n_d = preprocessing.normalize([d_array]) #normalized density
pH_array = np.array(wine['pH'])
n_pH = preprocessing.normalize([pH_array]) #normalized pH
su_array = np.array(wine['sulphates'])
n_su = preprocessing.normalize([su_array]) #normalized sulphates
al_array = np.array(wine['alcohol'])
n_al = preprocessing.normalize([al_array]) #normalized alcohol

#normalization for labels
q_array = np.array(wine['quality'])
n_q = preprocessing.normalize([q_array]) #normalized quality


print(f_array)
print(n_f)
print(n_su)
print(n_q)
